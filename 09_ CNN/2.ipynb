# %%
#-*- coding: utf-8 -*-

from keras.datasets import cifar10
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint,EarlyStopping

import matplotlib.pyplot as plt
import numpy
import os
import tensorflow as tf

# seed 값 설정
seed = 0
numpy.random.seed(seed)
tf.random.set_seed(3)

# 데이터 불러오기

(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

for i in range(10):
    plt.imshow(X_train[i])
    plt.xlabel(class_names[Y_train[i][0]])
    plt.show()
    
X_train = X_train.reshape(X_train.shape[0], 32, 32, 3).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 32, 32, 3).astype('float32') / 255
Y_train = np_utils.to_categorical(Y_train)
Y_test = np_utils.to_categorical(Y_test)
    
# 컨볼루션 신경망의 설정
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=(32, 32, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128,  activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# 모델 최적화 설정
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# 모델의 실행
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=30, batch_size=200, verbose=1, callbacks=[early_stopping_callback,checkpointer])

# 테스트 정확도 출력
print("\n Test Accuracy: %.4f" % (model.evaluate(X_test, Y_test)[1]))

# 테스트 셋의 오차
y_vloss = history.history['val_loss']

# 학습셋의 오차
y_loss = history.history['loss']

# 그래프로 표현
x_len = numpy.arange(len(y_loss))
plt.plot(x_len, y_vloss, marker='.', c="red", label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

# 그래프에 그리드를 주고 레이블을 표시
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
# Out:
# Using TensorFlow backend.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 142s 3ms/step - loss: 1.6601 - accuracy: 0.4023 - val_loss: 1.2872 - val_accuracy: 0.5480
#
# Epoch 00001: val_loss improved from inf to 1.28716, saving model to ./model/01-1.2872.hdf5
# Epoch 2/30
# 50000/50000 [==============================] - 148s 3ms/step - loss: 1.3133 - accuracy: 0.5338 - val_loss: 1.0924 - val_accuracy: 0.6218
#
# Epoch 00002: val_loss improved from 1.28716 to 1.09235, saving model to ./model/02-1.0924.hdf5
# Epoch 3/30
# 50000/50000 [==============================] - 149s 3ms/step - loss: 1.1771 - accuracy: 0.5849 - val_loss: 1.0223 - val_accuracy: 0.6477
#
# Epoch 00003: val_loss improved from 1.09235 to 1.02225, saving model to ./model/03-1.0223.hdf5
# Epoch 4/30
# 50000/50000 [==============================] - 157s 3ms/step - loss: 1.0867 - accuracy: 0.6140 - val_loss: 0.9843 - val_accuracy: 0.6547
#
# Epoch 00004: val_loss improved from 1.02225 to 0.98426, saving model to ./model/04-0.9843.hdf5
# Epoch 5/30
# 50000/50000 [==============================] - 153s 3ms/step - loss: 1.0306 - accuracy: 0.6366 - val_loss: 0.9291 - val_accuracy: 0.6758
#
# Epoch 00005: val_loss improved from 0.98426 to 0.92908, saving model to ./model/05-0.9291.hdf5
# Epoch 6/30
# 50000/50000 [==============================] - 150s 3ms/step - loss: 0.9851 - accuracy: 0.6529 - val_loss: 0.9357 - val_accuracy: 0.6731
#
# Epoch 00006: val_loss did not improve from 0.92908
# Epoch 7/30
# 50000/50000 [==============================] - 156s 3ms/step - loss: 0.9345 - accuracy: 0.6694 - val_loss: 0.8976 - val_accuracy: 0.6869
#
# Epoch 00007: val_loss improved from 0.92908 to 0.89756, saving model to ./model/07-0.8976.hdf5
# Epoch 8/30
# 50000/50000 [==============================] - 155s 3ms/step - loss: 0.8987 - accuracy: 0.6817 - val_loss: 0.8875 - val_accuracy: 0.6913
#
# Epoch 00008: val_loss improved from 0.89756 to 0.88748, saving model to ./model/08-0.8875.hdf5
# Epoch 9/30
# 50000/50000 [==============================] - 156s 3ms/step - loss: 0.8695 - accuracy: 0.6902 - val_loss: 0.8677 - val_accuracy: 0.6995
#
# Epoch 00009: val_loss improved from 0.88748 to 0.86773, saving model to ./model/09-0.8677.hdf5
# Epoch 10/30
# 50000/50000 [==============================] - 158s 3ms/step - loss: 0.8321 - accuracy: 0.7012 - val_loss: 0.8705 - val_accuracy: 0.6972
#
# Epoch 00010: val_loss did not improve from 0.86773
# Epoch 11/30
# 50000/50000 [==============================] - 156s 3ms/step - loss: 0.8086 - accuracy: 0.7137 - val_loss: 0.8640 - val_accuracy: 0.7008
#
# Epoch 00011: val_loss improved from 0.86773 to 0.86404, saving model to ./model/11-0.8640.hdf5
# Epoch 12/30
# 50000/50000 [==============================] - 154s 3ms/step - loss: 0.7768 - accuracy: 0.7198 - val_loss: 0.8709 - val_accuracy: 0.7007
#
# Epoch 00012: val_loss did not improve from 0.86404
# Epoch 13/30
# 50000/50000 [==============================] - 155s 3ms/step - loss: 0.7525 - accuracy: 0.7294 - val_loss: 0.8587 - val_accuracy: 0.7068
#
# Epoch 00013: val_loss improved from 0.86404 to 0.85875, saving model to ./model/13-0.8587.hdf5
# Epoch 14/30
# 50000/50000 [==============================] - 152s 3ms/step - loss: 0.7221 - accuracy: 0.7402 - val_loss: 0.8588 - val_accuracy: 0.7050
#
# Epoch 00014: val_loss did not improve from 0.85875
# Epoch 15/30
# 50000/50000 [==============================] - 157s 3ms/step - loss: 0.6993 - accuracy: 0.7467 - val_loss: 0.8756 - val_accuracy: 0.7005
#
# Epoch 00015: val_loss did not improve from 0.85875
# Epoch 16/30
# 50000/50000 [==============================] - 155s 3ms/step - loss: 0.6765 - accuracy: 0.7556 - val_loss: 0.8545 - val_accuracy: 0.7119
#
# Epoch 00016: val_loss improved from 0.85875 to 0.85451, saving model to ./model/16-0.8545.hdf5
# Epoch 17/30
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.6503 - accuracy: 0.7636 - val_loss: 0.8692 - val_accuracy: 0.7087
#
# Epoch 00017: val_loss did not improve from 0.85451
# Epoch 18/30
# 50000/50000 [==============================] - 163s 3ms/step - loss: 0.6313 - accuracy: 0.7696 - val_loss: 0.8509 - val_accuracy: 0.7095
#
# Epoch 00018: val_loss improved from 0.85451 to 0.85094, saving model to ./model/18-0.8509.hdf5
# Epoch 19/30
# 50000/50000 [==============================] - 149s 3ms/step - loss: 0.6089 - accuracy: 0.7784 - val_loss: 0.8625 - val_accuracy: 0.7150
#
# Epoch 00019: val_loss did not improve from 0.85094
# Epoch 20/30
# 50000/50000 [==============================] - 151s 3ms/step - loss: 0.5980 - accuracy: 0.7804 - val_loss: 0.8887 - val_accuracy: 0.7063
#
# Epoch 00020: val_loss did not improve from 0.85094
# Epoch 21/30
# 50000/50000 [==============================] - 155s 3ms/step - loss: 0.5745 - accuracy: 0.7886 - val_loss: 0.8994 - val_accuracy: 0.7044
#
# Epoch 00021: val_loss did not improve from 0.85094
# Epoch 22/30
# 50000/50000 [==============================] - 149s 3ms/step - loss: 0.5619 - accuracy: 0.7929 - val_loss: 0.8852 - val_accuracy: 0.7111
#
# Epoch 00022: val_loss did not improve from 0.85094
# Epoch 23/30
# 50000/50000 [==============================] - 146s 3ms/step - loss: 0.5486 - accuracy: 0.7975 - val_loss: 0.8934 - val_accuracy: 0.7098
#
# Epoch 00023: val_loss did not improve from 0.85094
# Epoch 24/30
# 50000/50000 [==============================] - 146s 3ms/step - loss: 0.5330 - accuracy: 0.8012 - val_loss: 0.8941 - val_accuracy: 0.7118
#
# Epoch 00024: val_loss did not improve from 0.85094
# Epoch 25/30
# 50000/50000 [==============================] - 147s 3ms/step - loss: 0.5163 - accuracy: 0.8090 - val_loss: 0.9121 - val_accuracy: 0.7108
#
# Epoch 00025: val_loss did not improve from 0.85094
# Epoch 26/30
# 50000/50000 [==============================] - 148s 3ms/step - loss: 0.5011 - accuracy: 0.8131 - val_loss: 0.9272 - val_accuracy: 0.7114
#
# Epoch 00026: val_loss did not improve from 0.85094
# Epoch 27/30
# 50000/50000 [==============================] - 147s 3ms/step - loss: 0.4960 - accuracy: 0.8151 - val_loss: 0.9370 - val_accuracy: 0.7109
#
# Epoch 00027: val_loss did not improve from 0.85094
# Epoch 28/30
# 50000/50000 [==============================] - 173s 3ms/step - loss: 0.4820 - accuracy: 0.8197 - val_loss: 0.9427 - val_accuracy: 0.7110
#
# Epoch 00028: val_loss did not improve from 0.85094
# 10000/10000 [==============================] - 9s 863us/step
#
#  Test Accuracy: 0.7110

# %%
import numpy as np

Y_prediction = model.predict(X_test)


for i in range(10):
    prediction = Y_prediction[i]
    
    n = np.argmax(prediction)
    label = np.argmax(Y_test[i])
    
    print('Actual Class: ' + str(label) + ' => Expect class: ' + str(n))
# Out:
# Actual Class: 3 => Expect class: 3
# Actual Class: 8 => Expect class: 1
# Actual Class: 8 => Expect class: 8
# Actual Class: 0 => Expect class: 0
# Actual Class: 6 => Expect class: 6
# Actual Class: 6 => Expect class: 6
# Actual Class: 1 => Expect class: 1
# Actual Class: 6 => Expect class: 6
# Actual Class: 3 => Expect class: 3
# Actual Class: 1 => Expect class: 1

# %%
from keras.models import load_model


#-*- coding: utf-8 -*-

from keras.datasets import cifar10
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint,EarlyStopping

import matplotlib.pyplot as plt
import numpy
import os
import tensorflow as tf

# seed 값 설정
seed = 0
numpy.random.seed(seed)
tf.random.set_seed(3)

# 데이터 불러오기

(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

for i in range(10):
    plt.imshow(X_train[i])
    plt.xlabel(class_names[Y_train[i][0]])
    plt.show()
    
X_train = X_train.reshape(X_train.shape[0], 32, 32, 3).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 32, 32, 3).astype('float32') / 255
Y_train = np_utils.to_categorical(Y_train)
Y_test = np_utils.to_categorical(Y_test)

model = load_model('./model/18-0.8623.hdf5')

import numpy as np

Y_prediction = model.predict(X_test)


for i in range(10):
    prediction = Y_prediction[i]
    
    n = np.argmax(prediction)
    label = np.argmax(Y_test[i])
    
    print('Actual Class: ' + str(label) + ' => Expect class: ' + str(n))

# %%
#-*- coding: utf-8 -*-

from keras.datasets import cifar10
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint,EarlyStopping

import matplotlib.pyplot as plt
import numpy
import os
import tensorflow as tf
from keras.models import load_model


# seed 값 설정
seed = 0
numpy.random.seed(seed)
tf.random.set_seed(3)

# 데이터 불러오기

(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dogq5', 'frog', 'horse', 'ship', 'truck']

for i in range(10):
    plt.imshow(X_train[i])
    plt.xlabel(class_names[Y_train[i][0]])
    plt.show()

print(X_train.shape)

X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
Y_train = np_utils.to_categorical(Y_train)
Y_test = np_utils.to_categorical(Y_test)


model = load_model('./model/18-0.8623.hdf5')

import numpy as np

Y_prediction = model.predict(X_test)


for i in range(10):
    prediction = Y_prediction[i]
    
    n = np.argmax(prediction)
    label = np.argmax(Y_test[i])
    
    print('Actual Class: ' + str(label) + ' => Expect class: ' + str(n))
